# %%
# %load_ext dotenv
# %dotenv

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import clear_output
# from qiskit_machine_learning.optimizers import COBYLA
from qiskit_machine_learning.utils import algorithm_globals

from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier
from qiskit_machine_learning.neural_networks import EstimatorQNN

algorithm_globals.random_seed = 42
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 7
#       4 # from qiskit_machine_learning.optimizers import COBYLA
#       5 from qiskit_machine_learning.utils import algorithm_globals
# ----> 7 from qiskit_machine_learning.algorithms.classifiers import NeuralNetworkClassifier
#       8 from qiskit_machine_learning.neural_networks import EstimatorQNN
#      10 algorithm_globals.random_seed = 42
#
# File ~/anaconda3/envs/perceptron/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/__init__.py:81
#       1 # This code is part of a Qiskit project.
#       2 #
#       3 # (C) Copyright IBM 2021, 2024.
#    (...)     10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 Quantum machine learning algorithms (:mod:`qiskit_machine_learning.algorithms`)
#      15 ===============================================================================
#    (...)     79    QBayesian
#      80 """
# ---> 81 from .trainable_model import TrainableModel
#      82 from .serializable_model import SerializableModelMixin
#      83 from .objective_functions import (
#      84     ObjectiveFunction,
#      85     BinaryObjectiveFunction,
#      86     MultiClassObjectiveFunction,
#      87     OneHotObjectiveFunction,
#      88 )
#
# File ~/anaconda3/envs/perceptron/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/trainable_model.py:21
#      17 import numpy as np
#      19 from qiskit_machine_learning import QiskitMachineLearningError
# ---> 21 from .objective_functions import ObjectiveFunction
#      22 from .serializable_model import SerializableModelMixin
#      23 from ..optimizers import Optimizer, SciPyOptimizer, SLSQP, OptimizerResult, Minimizer
#
# File ~/anaconda3/envs/perceptron/lib/python3.12/site-packages/qiskit_machine_learning/algorithms/objective_functions.py:21
#      18 import numpy as np
#      20 from .. import optionals as _optionals
# ---> 21 from ..neural_networks import NeuralNetwork
#      22 from ..utils.loss_functions import Loss
#      24 if _optionals.HAS_SPARSE:
#      25     # pylint: disable=import-error
#
# File ~/anaconda3/envs/perceptron/lib/python3.12/site-packages/qiskit_machine_learning/neural_networks/__init__.py:60
#       1 # This code is part of a Qiskit project.
#       2 #
#       3 # (C) Copyright IBM 2019, 2024.
#    (...)     10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 Quantum neural networks (:mod:`qiskit_machine_learning.neural_networks`)
#      15 ========================================================================
#    (...)     57    LocalEffectiveDimension
#      58 """
# ---> 60 from .effective_dimension import EffectiveDimension, LocalEffectiveDimension
#      61 from .estimator_qnn import EstimatorQNN
#      62 from .neural_network import NeuralNetwork
#
# File ~/anaconda3/envs/perceptron/lib/python3.12/site-packages/qiskit_machine_learning/neural_networks/effective_dimension.py:23
#      21 from ..utils import algorithm_globals
#      22 from ..exceptions import QiskitMachineLearningError
# ---> 23 from .estimator_qnn import EstimatorQNN
#      24 from .neural_network import NeuralNetwork
#      26 logger = logging.getLogger(__name__)
#
# File ~/anaconda3/envs/perceptron/lib/python3.12/site-packages/qiskit_machine_learning/neural_networks/estimator_qnn.py:24
#      22 from qiskit.circuit import Parameter, QuantumCircuit
#      23 from qiskit.primitives.base import BaseEstimatorV2
# ---> 24 from qiskit.primitives import BaseEstimator, BaseEstimatorV1, Estimator, EstimatorResult
#      25 from qiskit.quantum_info import SparsePauliOp
#      26 from qiskit.quantum_info.operators.base_operator import BaseOperator
#
# ImportError: cannot import name 'BaseEstimator' from 'qiskit.primitives' (/home/lpawela/anaconda3/envs/perceptron/lib/python3.12/site-packages/qiskit/primitives/__init__.py)

# %% [markdown]
# ## Data preparation

# %%
num_inputs = 2
num_samples = 20
X = 2 * algorithm_globals.random.random([num_samples, num_inputs]) - 1
y01 = 1 * (np.sum(X, axis=1) >= 0)  # in { 0,  1}
y = 2 * y01 - 1  # in {-1, +1}
y_one_hot = np.zeros((num_samples, 2))
for i in range(num_samples):
    y_one_hot[i, y01[i]] = 1

for x, y_target in zip(X, y):
    if y_target == 1:
        plt.plot(x[0], x[1], "bo")
    else:
        plt.plot(x[0], x[1], "go")
plt.plot([-1, 1], [1, -1], "--", color="black")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 num_inputs = 2
#       2 num_samples = 20
# ----> 3 X = 2 * algorithm_globals.random.random([num_samples, num_inputs]) - 1
#       4 y01 = 1 * (np.sum(X, axis=1) >= 0)  # in { 0,  1}
#       5 y = 2 * y01 - 1  # in {-1, +1}
#
# NameError: name 'algorithm_globals' is not defined

# %%
def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

# %%
from qiskit.primitives import StatevectorEstimator as Estimator

estimator = Estimator()
estimator_qnn = EstimatorQNN(circuit=qc, estimator=estimator)

# %%
estimator_classifier = NeuralNetworkClassifier(
    estimator_qnn, optimizer=COBYLA(maxiter=60), callback=callback_graph
)

# %%
estimator_qnn.forward(X[0, :], algorithm_globals.random.random(estimator_qnn.num_weights))

# %%
# create empty array for callback to store evaluations of the objective function
objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)

# fit classifier to data
estimator_classifier.fit(X, y)

# return to default figsize
plt.rcParams["figure.figsize"] = (6, 4)

# score classifier
estimator_classifier.score(X, y)

# %%
# evaluate data points
y_predict = estimator_classifier.predict(X)

# plot results
# red == wrongly classified
for x, y_target, y_p in zip(X, y, y_predict):
    if y_target == 1:
        plt.plot(x[0], x[1], "bo")
    else:
        plt.plot(x[0], x[1], "go")
    if y_target != y_p:
        plt.scatter(x[0], x[1], s=200, facecolors="none", edgecolors="r", linewidths=2)
plt.plot([-1, 1], [1, -1], "--", color="black")
plt.show()

# %%
estimator_classifier.weights
