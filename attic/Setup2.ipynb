# %% [markdown]
# # Ustawienie środowiska pracy
#
# W tym szkoleniu będziemy przedewszystkim używać języka programowania Python. Jest on często używany jako API do komputerów kwantowych. Poniższa instrukcja pozwoli przygotować gotowe środowisko do pracy.
#
# ### Windows
#
# 1. Pobierz instalator:
#     * Przejdź na stronę [python.org/downloads/windows](python.org/downloads/windows) i pobierz instalator dla Pythona w wersji 3.12.9 odpowiedni dla twojego komputera. [Tutaj](https://support.microsoft.com/pl-pl/office/ustalanie-czy-na-komputerze-dzia%C5%82a-32-bitowa-czy-64-bitowa-wersja-systemu-operacyjnego-windows-aac162a1-0cb3-46f2-888f-2f22897396ce) jest instrukcja jak sprawdzić czy się posiada 32-bitową czy 64-bitową wersje systemu operacyjnego.
#
# 2. Uruchom instalator:
#
#     * Uruchom pobrany plik.
#     * Zaznacz opcję „Add python.exe to PATH” – to ułatwi korzystanie z Pythona z wiersza poleceń.
#     * Kliknij „Install Now” i poczekaj na zakończenie instalacji. Zainstaluje to język razem z przydatnymi dodatkowymi programami i dokumentacją.
#
# 3. Zweryfikuj instalacje:
#
#     * Otwórz wiersz poleceń. Najprościej to zrobić wciskając Win + r, wpisując `cmd` w otwartym oknie a następnie wciskając Enter. W wierszu poleceń wpisz:
#     ```bash
#     python --version
#     ```
#     Powinieneś zobaczyć zainstalowaną wersję Pythona (w naszym wypadku 3.12.9).
#
# 4. Utwórz środowisko wirtualne:
#     * W dowolnym katalogu utwórz folder projektu i wejdź do niego, np.
#
#     ```bash
#     mkdir moj_projekt
#     cd moj_projekt
#     ```
#     * Utwórz środowisko wirtualne. W tym przykładzie nazwiemy je `warsztaty`
#
#     ```bash
#     python -m venv warsztaty
#     ```
#     * Aktywuj środowisko:
#      ```bash
#      warsztaty\Scripts\activate
#      ```
#     * Aby dezaktywować środowisko, wpisz:
#     ```bash
#     deactivate
#     ```
#
# ### Linux (Debian/Ubuntu):
#
# Python jest preinstalowany na większości dystrybucji Linuxa. Poniższa instrukcja pozwoli zainstalować Pythona w wymaganej wersji.
#
# 1. Zainstaluj Pythona:
#     * Otwórz Terminal i wykonaj aktualizację pakietów:
#     ```bash
#     sudo apt update
#     ```
#     * Zainstaluj Pythona wraz z narzędziami:
#     ```bash
#     sudo apt install python3.12
#     ```
#     Zainstaluje to najaktualniejszą wersję pythona 3.12.x. Nie ma problemu jeżeli będzie to wcześniejsza wejsa niż 3.12.9
#
# 2. Zweryfikuj instalacje:
#
#     * W terminalu wpisz
#     ```bash
#     python3.12 --version
#     ```
#     Powinieneś zobaczyć zainstalowaną wersję Pythona.
#
# 3. Utwórz środowisko wirtualne:
#     * W dowolnym katalogu utwórz folder projektu i wejdź do niego, np.
#
#     ```bash
#     mkdir moj_projekt
#     cd moj_projekt
#     ```
#     * Utwórz środowisko wirtualne. W tym przykładzie nazwiemy je `warsztaty`
#
#     ```bash
#     python3.12 -m venv warsztaty
#     ```
#     * Aktywuj środowisko:
#      ```bash
#      source warsztaty/Scripts/activate
#      ```
#     * Aby dezaktywować środowisko, wpisz:
#     ```bash
#     deactivate
#     ```
#
# ### MacOs
#
# 1. Instalacja Pythona:
#
#     * Opcja 1: Oficjalny instalator
#     Przejdź na [python.org/downloads/mac-osx](python.org/downloads/mac-osx) i pobierz instalator dla Pythona w wersji 3.12.9 a następnie postępuj zgodnie z instrukcjami.
#     * Opcja 2: Homebrew
#     Jeśli masz zainstalowany Homebrew, uruchom Terminal i wpisz:
#     ```bash
#     brew install python@3.12
#     ```
# 2. Zweryfikuj instalacje:
#
#     * W terminalu wpisz
#     ```bash
#     python3.12 --version
#     ```
#     Powinieneś zobaczyć zainstalowaną wersję Pythona.
#
# 3. Utwórz środowisko wirtualne:
#     * W dowolnym katalogu utwórz folder projektu i wejdź do niego, np.
#
#     ```bash
#     mkdir moj_projekt
#     cd moj_projekt
#     ```
#     * Utwórz środowisko wirtualne. W tym przykładzie nazwiemy je `warsztaty`
#
#     ```bash
#     python3.12 -m venv warsztaty
#     ```
#     * Aktywuj środowisko:
#      ```bash
#      source warsztaty/Scripts/activate
#      ```
#     * Aby dezaktywować środowisko, wpisz:
#     ```bash
#     deactivate
#     ```
#
# ## Alternatywa
#
# Alternatywą dla używania venv jest środowisko conda.
#
# 1. Zainstaluj conda
#
#     * Przejdź na oficjalną stronę [Anaconda](https://www.anaconda.com/), gdzie możesz pobrać wybrany instalator (Miniconda, Anaconda Distribution lub Miniforge). Więcej informacji o każdym z tych instalatorów znajdziesz w [dokumentacji](https://docs.conda.io/projects/conda/en/stable/user-guide/install/index.html) instalacji conda. Po pobraniu, zainstaluj conda.
#
# 2. Utwórz środowisko wirtualne.
#     * W teminalu/anaconda prompt wpisz:
#
#     ```bash
#     conda create --name szkolenia
#     ```
# 3. Aktywuj środowisko:
#
#     * W teminalu/anaconda prompt wpisz:
#     ```bash
#     conda activate myenv
#     ```
#     * By zdeaktywować środowisko wpisz:
#     ```bash
#     conda deactivate
#     ```
# 4. Zainstaluj Pythona w wymaganej wersji. Conda pozwala operować różnymi wersjami pythona dla każdego środowiska.
#      * W teminalu/anaconda prompt wpisz:
#     ```bash
#     conda install python=3.12
#     ```
#     * Zweryfikuj instalacje wpisując
#     ```bash
#     python --version
#     ```
#
# ## dalsze kroki
#
# 1. Zainstaluj Ipykernel. Jest to backend potrzebny by móc używać Jupyter notebook. W terminalu mając aktywowane środowisko wpisz
# ```bash
# pip install ipykernel
# ```
#
# 2. Uruchom poniższą komórkę, aby zainstalować wymagane pakiety. Pamiętaj by ustawić jądro (kernel) w używanym programie na utworzone środowisko (w Visual Studio Code można to zrobić w prawym górnym rogu)

# %%
# %pip install -r requirements.txt
# Out:
# Collecting matplotlib==3.10.0 (from -r requirements.txt (line 1))
#   Using cached matplotlib-3.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting networkx==3.4.2 (from -r requirements.txt (line 2))
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting numpy==2.0.2 (from -r requirements.txt (line 3))
#   Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting pandas==2.2.3 (from -r requirements.txt (line 4))
#   Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting tqdm==4.67.1 (from -r requirements.txt (line 5))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting dwave-ocean-sdk==8.2.0 (from -r requirements.txt (line 6))
#   Using cached dwave_ocean_sdk-8.2.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.10.0->-r requirements.txt (line 1))
#   Using cached contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib==3.10.0->-r requirements.txt (line 1))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib==3.10.0->-r requirements.txt (line 1))
#   Downloading fonttools-4.56.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib==3.10.0->-r requirements.txt (line 1))
#   Using cached kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /home/tsmierzchalski/anaconda3/envs/test/lib/python3.12/site-packages (from matplotlib==3.10.0->-r requirements.txt (line 1)) (24.2)
# Collecting pillow>=8 (from matplotlib==3.10.0->-r requirements.txt (line 1))
#   Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib==3.10.0->-r requirements.txt (line 1))
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tsmierzchalski/anaconda3/envs/test/lib/python3.12/site-packages (from matplotlib==3.10.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.2.3->-r requirements.txt (line 4))
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.3->-r requirements.txt (line 4))
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting dimod==0.12.18 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dimod-0.12.18-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting dwave-cloud-client==0.13.3 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_cloud_client-0.13.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting dwave-gate==0.3.3 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_gate-0.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting dwave-hybrid==0.6.13 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_hybrid-0.6.13-py3-none-any.whl.metadata (4.3 kB)
# Collecting dwave-inspector==0.5.2 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_inspector-0.5.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting dwave-networkx==0.8.16 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_networkx-0.8.16-py3-none-any.whl.metadata (2.6 kB)
# Collecting dwave-optimization==0.5.1 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_optimization-0.5.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (18 kB)
# Collecting dwave-preprocessing==0.6.7 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_preprocessing-0.6.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting dwave-samplers==1.4.0 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_samplers-1.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Collecting dwave-system==1.29.0 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwave_system-1.29.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting dwavebinarycsp==0.3.1 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached dwavebinarycsp-0.3.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting minorminer==0.2.17 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached minorminer-0.2.17-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting penaltymodel==1.2.0 (from dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached penaltymodel-1.2.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting requests<3,>=2.25 (from requests[socks]<3,>=2.25->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting urllib3<3,>=1.26 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pydantic<3,>=2 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting homebase<2,>=1.0 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached homebase-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting click<9,>=7.0 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting plucky<0.5,>=0.4.3 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached plucky-0.4.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting diskcache<6,>=5.2.1 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting werkzeug<4,>=2.2 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting typing-extensions<5,>=4.5.0 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting authlib<2,>=1.2 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Downloading authlib-1.5.1-py2.py3-none-any.whl.metadata (3.9 kB)
# Collecting importlib_metadata>=5.0.0 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting orjson>=3.10 (from dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached orjson-3.10.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting Flask<4,>=2.2 (from dwave-inspector==0.5.2->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting scipy>=1.7.3 (from dwave-system==1.29.0->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting fasteners>=0.15 (from minorminer==0.2.17->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six>=1.5 in /home/tsmierzchalski/anaconda3/envs/test/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib==3.10.0->-r requirements.txt (line 1)) (1.17.0)
# Collecting cryptography (from authlib<2,>=1.2->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Downloading cryptography-44.0.2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.7 kB)
# Collecting Jinja2>=3.1.2 (from Flask<4,>=2.2->dwave-inspector==0.5.2->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2 (from Flask<4,>=2.2->dwave-inspector==0.5.2->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.9 (from Flask<4,>=2.2->dwave-inspector==0.5.2->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting zipp>=3.20 (from importlib_metadata>=5.0.0->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3,>=2->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]<3,>=2.25->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug<4,>=2.2->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting cffi>=1.12 (from cryptography->authlib<2,>=1.2->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached cffi-1.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography->authlib<2,>=1.2->dwave-cloud-client==0.13.3->dwave-ocean-sdk==8.2.0->-r requirements.txt (line 6))
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Using cached matplotlib-3.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
# Using cached pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached dwave_ocean_sdk-8.2.0-py3-none-any.whl (8.3 kB)
# Using cached dimod-0.12.18-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.0 MB)
# Using cached dwave_cloud_client-0.13.3-py3-none-any.whl (160 kB)
# Using cached dwave_gate-0.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Using cached dwave_hybrid-0.6.13-py3-none-any.whl (78 kB)
# Using cached dwave_inspector-0.5.2-py3-none-any.whl (30 kB)
# Using cached dwave_networkx-0.8.16-py3-none-any.whl (103 kB)
# Using cached dwave_optimization-0.5.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (2.8 MB)
# Using cached dwave_preprocessing-0.6.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
# Using cached dwave_samplers-1.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Using cached dwave_system-1.29.0-py3-none-any.whl (101 kB)
# Using cached dwavebinarycsp-0.3.1-py3-none-any.whl (35 kB)
# Using cached minorminer-0.2.17-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.9 MB)
# Using cached penaltymodel-1.2.0-py3-none-any.whl (36 kB)
# Using cached contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 37.4 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Using cached pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Using cached tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading authlib-1.5.1-py2.py3-none-any.whl (231 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Using cached fasteners-0.19-py3-none-any.whl (18 kB)
# Using cached flask-3.1.0-py3-none-any.whl (102 kB)
# Using cached homebase-1.0.1-py2.py3-none-any.whl (11 kB)
# Using cached importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Using cached orjson-3.10.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
# Using cached plucky-0.4.3-py2.py3-none-any.whl (10 kB)
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 67.7 MB/s eta 0:00:00a 0:00:01
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading cryptography-44.0.2-cp39-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 59.3 MB/s eta 0:00:00
# Using cached cffi-1.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (479 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pytz, plucky, homebase, zipp, urllib3, tzdata, typing-extensions, tqdm, PySocks, pyparsing, pycparser, pillow, orjson, numpy, networkx, MarkupSafe, kiwisolver, itsdangerous, idna, fonttools, fasteners, diskcache, cycler, click, charset-normalizer, certifi, blinker, annotated-types, werkzeug, scipy, requests, pydantic-core, pandas, Jinja2, importlib_metadata, dwave-optimization, dwave-gate, dimod, contourpy, cffi, pydantic, penaltymodel, matplotlib, Flask, dwave-samplers, dwave-preprocessing, dwave-networkx, cryptography, minorminer, dwavebinarycsp, authlib, dwave-cloud-client, dwave-system, dwave-inspector, dwave-hybrid, dwave-ocean-sdk
# Successfully installed Flask-3.1.0 Jinja2-3.1.5 MarkupSafe-3.0.2 PySocks-1.7.1 annotated-types-0.7.0 authlib-1.5.1 blinker-1.9.0 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 click-8.1.8 contourpy-1.3.1 cryptography-44.0.2 cycler-0.12.1 dimod-0.12.18 diskcache-5.6.3 dwave-cloud-client-0.13.3 dwave-gate-0.3.3 dwave-hybrid-0.6.13 dwave-inspector-0.5.2 dwave-networkx-0.8.16 dwave-ocean-sdk-8.2.0 dwave-optimization-0.5.1 dwave-preprocessing-0.6.7 dwave-samplers-1.4.0 dwave-system-1.29.0 dwavebinarycsp-0.3.1 fasteners-0.19 fonttools-4.56.0 homebase-1.0.1 idna-3.10 importlib_metadata-8.6.1 itsdangerous-2.2.0 kiwisolver-1.4.8 matplotlib-3.10.0 minorminer-0.2.17 networkx-3.4.2 numpy-2.0.2 orjson-3.10.15 pandas-2.2.3 penaltymodel-1.2.0 pillow-11.1.0 plucky-0.4.3 pycparser-2.22 pydantic-2.10.6 pydantic-core-2.27.2 pyparsing-3.2.1 pytz-2025.1 requests-2.32.3 scipy-1.15.2 tqdm-4.67.1 typing-extensions-4.12.2 tzdata-2025.1 urllib3-2.3.0 werkzeug-3.1.3 zipp-3.21.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Kilka słów o używanych pakietach
#
# * NumPy - Standardowy pakiet używany do obliczeń numerycznych. Potrzebujemy go do efektywnego wykonywania operacji na macierzach.
# * Pandas - Standardowy pakiet używany do obróbki i pracy z danymi. Potrzebujemy małej części do wczytywania danych.
# * Matplotlib - Będziemy go używać do tworzenia wykresów.
# * Networkx - Standardowy pakiet do pracy z grafami.
# * tqdm - Mały pakiet. Pozwala renderować w konsoli ładny pasek postępu.
#
# ### dwave-ocean-sdk
#
# Duży pakiet składający się z wielu podpakietów. Generalnie jest to biblioteka używana do komunikacji z dwave. Ponadto posiada wiele funkcjonalności przydatnych przy pracy z używanymi przez nas modelami.

# %% [markdown]
# ## Dodatkowe wymagania odnośnie GPU
#
# Szęść szkolenia będzie skupiona na wykorzystaniu możliwości GPU do wspierania obliczeń. Jest to związane z pewnymi dodatkowymi wymaganiami
#
# 1. Procesor graficzny NVIDIA CUDA o możliwości obliczeniowej (Compute Capability) 3.0 lub wyższej. Niemal wszystkie współczesne karty graficzne spełniają to wymaganie. Listę wspieranych urządzeń znajdziesz [tutaj](https://developer.nvidia.com/cuda-gpus).
# 2. [CUDA Toolkit](https://developer.nvidia.com/cuda-toolkit): v11.2 / v11.3 / v11.4 / v11.5 / v11.6 / v11.7 / v11.8 / v12.0 / v12.1 / v12.2 / v12.3 / v12.4 / v12.5 / v12.6
#
# By sprawdzić wersję CUDA Toolkit wpisz `nvcc --version` w terminalu.
#
# Będziemy używać jednego dodatkowego pakietu - CuPy. Jest to standardowy pakiet w Pythonie używany do interakcji z GPU. Inny popularnie używany pakiet to Numba. Komanda do instalacji CuPy różni się w zależności od posiadanej wersji CUDA Toolkit. Jeżeli występują jakies problemy z instalacją zajżyj [tutaj](https://docs.cupy.dev/en/stable/install.html).

# %%
# Instalacja CuPy dla v11.2 ~ 11.8 

# %pip install cupy-cuda11x

# %%
# Instalacja CuPy dla v12.x 
	
# %pip install cupy-cuda12x
# Out:
# Collecting cupy-cuda12x
#   Downloading cupy_cuda12x-13.4.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy<2.3,>=1.22 in /home/tsmierzchalski/anaconda3/envs/test/lib/python3.12/site-packages (from cupy-cuda12x) (2.0.2)
# Collecting fastrlock>=0.5 (from cupy-cuda12x)
#   Using cached fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# Downloading cupy_cuda12x-13.4.0-cp312-cp312-manylinux2014_x86_64.whl (105.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 MB 51.0 MB/s eta 0:00:0000:010:01
# Using cached fastrlock-0.8.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (53 kB)
# Installing collected packages: fastrlock, cupy-cuda12x
# Successfully installed cupy-cuda12x-13.4.0 fastrlock-0.8.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Dodatkowe wymagania do puszczania benchmarków

# %% [markdown]
# ## Bruteforce
#
# Do uruchomiania pakietu `omnisolver-bruteforce` będziemy potrzebować nowego jądra (kernelu) z Pythonem w wersji 3.9. [Tutaj](https://github.com/euro-hpc-pl/omnisolver-bruteforce) można znaleźć instrukcje jak zainstalować paczkę mając gotowe nowe środowisko wirtualne. Ponadto będziemy potrzebowali paczek `dimod` i `tqdm`.

# %% [raw]
# pip install tqdm

# %% [markdown]
# ## Simulated Bifurcation
#
# By zainstalować zewnęczną paczkę `Simulated Bifurcation for Python` należy użyć poniższej komendy. Można to zrobić na głownym środowisku używanym podczas tych szkoleń.

# %% [raw]
# pip install git+https://github.com/bqth29/simulated-bifurcation-algorithm.git

# %% [markdown]
# Można Podczas instalacji mogą pojawić się błędy związane z wersją `NumPy`. Nie jest to poważny problem i dla naszych potrzeb nie daje żadnej różnicy.
