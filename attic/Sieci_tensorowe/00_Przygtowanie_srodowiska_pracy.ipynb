# %% [markdown]
# # Julia
#
# Julia jest jednym z popularniejszych języków programowania
#
# Instrukcje jak zainstalować język Julia można znaleźć [tutaj](https://julialang.org/install/). Zalecane jest skorzystanie z `juliaup`

# %% [markdown]
# uruchom Julia w terminalu/wierszu poleceń poprzez wpisanie komendy:

# %%
Julia

# %% [markdown]
# Następnie aktywujemy managera pakietów poprzez naciśnięcie `]` i wpisujemy

# %%
add IJulia

# %% [markdown]
# Podobnie jak `IPython` jest to paczka wymagana by korzystać z Notebook.
#
# Następnie dodamy jeszcze biblioteki potrzebne w dalszej części szkolenia.

# %%
add CUDA
add TensorOperations
add SpinGlassPEPS

# %% [markdown]
# Teraz notebook powinien działać. Podobnie jak w przypadku pythona dodajemy wybieramy by kernelem była Julia
